# %%
import os
import pandas as pd
import numpy as np
import json
import yaml
import joblib
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.preprocessing import LabelEncoder

# -------------------------------
# 📂 PATHS
# -------------------------------
DATA_PATH = r"C:\Users\NXTWAVE\Downloads\Mineral Revenue Intelligence System\mineral_wise_revenue_collected.csv"
OUTPUT_DIR = r"C:\Users\NXTWAVE\Downloads\Mineral Revenue Intelligence System"

os.makedirs(OUTPUT_DIR, exist_ok=True)

# -------------------------------
# 📊 LOAD DATA
# -------------------------------
df = pd.read_csv(DATA_PATH)
print("✅ Data Loaded:", df.shape)

# -------------------------------
# 🧹 CLEANING
# -------------------------------
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")
df = df.ffill()

for col in df.columns:
    df[col] = df[col].astype(str)
    df[col] = df[col].str.replace(",", "", regex=False)
    df[col] = df[col].str.replace("₹", "", regex=False)
    df[col] = df[col].str.replace("$", "", regex=False)
    df[col] = pd.to_numeric(df[col], errors='ignore')

# -------------------------------
# 🎯 TARGET
# -------------------------------
numeric_cols = df.select_dtypes(include=np.number).columns.tolist()
if len(numeric_cols) == 0:
    raise Exception("❌ No numeric columns found")

target_col = numeric_cols[-1]
print("🎯 Target:", target_col)

# -------------------------------
# 🔤 ENCODING
# -------------------------------
for col in df.select_dtypes(include='object').columns:
    df[col] = LabelEncoder().fit_transform(df[col].astype(str))

# -------------------------------
# 🎯 FEATURES
# -------------------------------
X = df.drop(columns=[target_col])
y = df[target_col]

# -------------------------------
# 🦇 BAT ALGORITHM FEATURE SELECTION
# -------------------------------
def bat_feature_selection(X, y, n_bats=10, iterations=20):
    n_features = X.shape[1]

    positions = np.random.rand(n_bats, n_features)
    velocities = np.zeros((n_bats, n_features))
    freq = np.zeros(n_bats)

    pbest = positions.copy()
    pbest_scores = np.full(n_bats, -np.inf)

    def fitness(position):
        mask = (position > 0.5).astype(int)
        if np.sum(mask) == 0:
            return -np.inf

        cols = X.columns[mask == 1]
        X_sub = X[cols]

        X_train, X_test, y_train, y_test = train_test_split(X_sub, y, test_size=0.2)

        model = RandomForestRegressor(n_estimators=100)
        model.fit(X_train, y_train)
        preds = model.predict(X_test)

        return r2_score(y_test, preds)

    # Initial evaluation
    for i in range(n_bats):
        score = fitness(positions[i])
        pbest_scores[i] = score

    gbest = pbest[np.argmax(pbest_scores)]

    # Main loop
    for t in range(iterations):
        for i in range(n_bats):
            freq[i] = np.random.rand()
            velocities[i] = velocities[i] + (positions[i] - gbest) * freq[i]
            positions[i] = positions[i] + velocities[i]

            positions[i] = np.clip(positions[i], 0, 1)

            # Local search
            if np.random.rand() > 0.5:
                positions[i] = gbest + 0.01 * np.random.randn(n_features)

            score = fitness(positions[i])

            if score > pbest_scores[i]:
                pbest[i] = positions[i]
                pbest_scores[i] = score

        gbest = pbest[np.argmax(pbest_scores)]

    best_mask = (gbest > 0.5).astype(int)
    return X.columns[best_mask == 1]

print("🦇 Running Bat Algorithm Optimization...")
selected_features = bat_feature_selection(X, y)

print("✅ Selected Features:", list(selected_features))

X = X[selected_features]

# -------------------------------
# 🔀 SPLIT
# -------------------------------
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# -------------------------------
# 🌳 MODEL
# -------------------------------
model = RandomForestRegressor(n_estimators=200)
model.fit(X_train, y_train)

preds = model.predict(X_test)

mae = mean_absolute_error(y_test, preds)
r2 = r2_score(y_test, preds)

print(f"📊 MAE: {mae}")
print(f"📊 R2: {r2}")

# -------------------------------
# 📄 RESULTS CSV
# -------------------------------
results_df = pd.DataFrame({
    "Metric": ["MAE", "R2"],
    "Value": [mae, r2]
})

results_df.to_csv(os.path.join(OUTPUT_DIR, "ba_results.csv"), index=False)

# -------------------------------
# 📈 RESULTS GRAPH
# -------------------------------
plt.figure()
plt.bar(results_df["Metric"], results_df["Value"])
plt.title("BA Model Performance")
plt.savefig(os.path.join(OUTPUT_DIR, "ba_results_graph.png"))
plt.show()

# -------------------------------
# 📊 HEATMAP
# -------------------------------
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), cmap="coolwarm")
plt.title("BA Heatmap")
plt.savefig(os.path.join(OUTPUT_DIR, "ba_heatmap.png"))
plt.show()

# -------------------------------
# 📈 PREDICTIONS CSV
# -------------------------------
pred_df = pd.DataFrame({
    "actual": y_test,
    "predicted": preds
})

pred_df.to_csv(os.path.join(OUTPUT_DIR, "ba_predictions.csv"), index=False)

# -------------------------------
# 📉 PREDICTION GRAPH
# -------------------------------
plt.figure()
plt.plot(pred_df["actual"].values, label="Actual")
plt.plot(pred_df["predicted"].values, label="Predicted")
plt.legend()
plt.title("BA Prediction Graph")
plt.savefig(os.path.join(OUTPUT_DIR, "ba_prediction_graph.png"))
plt.show()

# -------------------------------
# 📊 ACCURACY GRAPH
# -------------------------------
plt.figure()
plt.bar(["R2"], [r2])
plt.title("BA Accuracy")
plt.savefig(os.path.join(OUTPUT_DIR, "ba_accuracy_graph.png"))
plt.show()

# -------------------------------
# 💾 SAVE MODEL
# -------------------------------
joblib.dump(model, os.path.join(OUTPUT_DIR, "ba_model.pkl"))

# -------------------------------
# 📄 YAML
# -------------------------------
config = {
    "model": "Bat Algorithm Optimized RandomForest",
    "features": list(selected_features),
    "target": target_col,
    "metrics": {"MAE": float(mae), "R2": float(r2)}
}

with open(os.path.join(OUTPUT_DIR, "ba_config.yaml"), "w") as f:
    yaml.dump(config, f)

# -------------------------------
# 📦 JSON
# -------------------------------
with open(os.path.join(OUTPUT_DIR, "ba_results.json"), "w") as f:
    json.dump(config, f, indent=4)

print("\n🚀 BA PROJECT COMPLETE! All files saved with 'ba_' prefix")
# Out:
# ✅ Data Loaded: (29, 12)
# 🎯 Target: 2024_-_2025
# 🦇 Running Bat Algorithm Optimization...
# C:\Users\NXTWAVE\AppData\Local\Temp\ipykernel_9544\2411860057.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')
# C:\Users\NXTWAVE\AppData\Local\Temp\ipykernel_9544\2411860057.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')
# C:\Users\NXTWAVE\AppData\Local\Temp\ipykernel_9544\2411860057.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df[col] = pd.to_numeric(df[col], errors='ignore')
# ...
